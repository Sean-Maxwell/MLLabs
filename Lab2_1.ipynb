# %% [markdown]
# # Lab 2 Bank list dataset

# %%
import pandas as pd
import numpy as py
import matplotlib.pyplot as plt
import statistics
import seaborn as sn

# %%
df = pd.read_csv(r"C:\Users\smaxw\Downloads\bank-fill-corrected.csv")
print (df.head())
# Out:
#    age           job  marital  education default  balance housing  \
# 0   58    management  married   tertiary      no     2143     yes
# 1   44    technician   single  secondary      no       29     yes
# 2   33  entrepreneur  married  secondary      no        2     yes
# 3   47   blue-collar  married    unknown      no     1506     yes
# 4   33       unknown   single    unknown      no        1      no
#
#   personal loan  contact  day last contact month  duration  Campaign  pdays  \
# 0            no  unknown                 5   may       261         1     -1
# 1            no  unknown                 5   may       151         1     -1
# 2           yes  unknown                 5   may        76         1     -1
# 3            no  unknown                 5   may        92         1     -1
# 4            no  unknown                 5   may       198         1     -1
#
#    previous poutcome deposit
# 0         0  unknown      no
# 1         0  unknown      no
# ...

# %% [markdown]
# ### 3.Conduct the following analysis; print data, print shape, describe the data and correlations of the attributes of the data.

# %%
##Testing that my code reads from the csv file
##original line of code I found --  print(df.Name.to_string(index=False))
print(df.age,df.job,df.education,df.housing)
# Out:
# 0        58
# 1        44
# 2        33
# 3        47
# 4        33
#          ..
# 45206    51
# 45207    71
# 45208    72
# 45209    57
# 45210    37
# Name: age, Length: 45211, dtype: int64 0          management
# 1          technician
# 2        entrepreneur
# 3         blue-collar
# 4             unknown
#              ...
# 45206      technician
# 45207         retired
# 45208         retired
# 45209     blue-collar
# 45210    entrepreneur
# Name: job, Length: 45211, dtype: object 0         tertiary
# 1        secondary
# 2        secondary
# 3          unknown
# 4          unknown
#            ...
# 45206     tertiary
# 45207      primary
# 45208    secondary
# 45209    secondary
# 45210    secondary
# Name: education, Length: 45211, dtype: object 0        yes
# 1        yes
# 2        yes
# 3        yes
# 4         no
#         ...
# 45206     no
# 45207     no
# 45208     no
# 45209     no
# 45210     no
# Name: housing, Length: 45211, dtype: object

# %%
##Describing the data, correlations and attributes.
print(df.shape)
print(df.describe)
print(df.corr)
# Out:
# (45211, 17)
# <bound method NDFrame.describe of        age           job   marital  education default  balance housing  \
# 0       58    management   married   tertiary      no     2143     yes
# 1       44    technician    single  secondary      no       29     yes
# 2       33  entrepreneur   married  secondary      no        2     yes
# 3       47   blue-collar   married    unknown      no     1506     yes
# 4       33       unknown    single    unknown      no        1      no
# ...    ...           ...       ...        ...     ...      ...     ...
# 45206   51    technician   married   tertiary      no      825      no
# 45207   71       retired  divorced    primary      no     1729      no
# 45208   72       retired   married  secondary      no     5715      no
# 45209   57   blue-collar   married  secondary      no      668      no
# 45210   37  entrepreneur   married  secondary      no     2971      no
#
# ...

# %% [markdown]
# ### 4. (print all graphs) Finally plot the data using: Univariate Plots, Density Plots, Skew, Correlation Plots, Scatter Plots.

# %%
df2 = pd.read_csv(r"C:\Users\smaxw\Downloads\bank-fill-corrected.csv",)

##density of age column
df.age.plot.density()
plt.show()

##Skew
#skewness=df.age.plot(kind = 'density')
#print(skewness)
#plt.show()

##Univariate/histogram graph of job column
df.job.hist(figsize=(20,5),rwidth=0.7)
plt.show()

##Scatter Plots of age an duration columns
plt.scatter(df.age,df.duration)
plt.show()

##Correlation Plot
corrMatrix = df.corr()
sn.heatmap(corrMatrix, annot=True)
plt.show()

# %% [markdown]
# ### 5. Pick any four attributes for each dataset and discuss them, for this you do not need to provide an additional numerical rationale or calculations, but using what you can infer from the graphs (part 4) and the analysis (part 3), provide insights to the data set. You may have to research the data points, and the overall aim is to identify any missing data or outliers if any.

# %% [markdown]
# ##### https://archive.ics.uci.edu/ml/datasets/Bank+Marketing
#
# ##### 1. Begining with the density/skew plot of the age columns. My understanding is that there are very litle to none outliers in the age columns that i can see. The density graph is positively skewed towards 65 years which is retirement age. Looking at the dataset itself with a jobs column it doesnt seem there is anyone working at an excessively old age. Hence why there is no outliers in the age column. No missing data in the age columns either.
#
# ##### 2. From the histogram I can see there is missing data there is a couple of hundred people with unknown ocupations. Over 16000 of people who as Managers. Under 2000 Technicians, under 10000 Entrepeneurs etc. From the graph there seems to be no outliers.
#
# ##### 3. Scatter plot for age and duration. To clarify duration is the last contact duration of the phone call in seconds I compared it to the age column to see if Age of the employee had any influence on the duration of the phone call. My conclusion is from my scatter plot the calls are typically the same duration and age has no influence on whether the call would be very brief/long.
#
# ##### 4.
